# %%
# Colab MEGA-SCRIPT
from google.colab import drive
drive.mount('/content/drive')

# !git clone https://github.com/1TMTD/survival-test.git
# %cd survival-test

print("Вибери сюжет: 1-Тінь і світло, 2-Музика лісу, 3-Книга часу")
choice = input("Номер: ")
story = "Shadow_and_Light" if choice=="1" else "Music_of_the_Forest" if choice=="2" else "Book_of_Time"

# !python generate_prompts.py {story}
# !zip -r /content/drive/MyDrive/survival-test/results_{story}.zip ./outputs
